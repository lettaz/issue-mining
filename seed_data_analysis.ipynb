# %%
import pandas as pd
from IPython.display import display
from github import Github

# Authenticate with the GitHub API using a personal access token
g = Github('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')

#Original starter dataset size
odf = 735669

# Load the CSV file into a pandas dataframe
df = pd.read_csv('results.csv', encoding='latin-1')

# Count the number of rows in the dataframe
data_num_rows = df.shape[0]

#Get percentage of rows that passed first filtering criteria, which repositories with the label feature
percentage = data_num_rows / odf * 100

# Display the number of rows in Jupyter notebook
print(f'The filtered dataset based on repositores with label feature has {data_num_rows} repositories, which is {percentage:.2f}% of the original dataset with {odf} repositories')
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# The filtered dataset based on repositores with label feature has 18282 repositories, which is 2.49% of the original dataset with 735669 repositories

# %%
# Filter the data based on the criteria
filtered_df = df[(df['stargazers'] > 500)]

# Count the number of rows in the filtered dataframe
num_rows = filtered_df.shape[0]

# Calculate the percentage of rows that passed the filtering criteria
percentage = num_rows / data_num_rows * 100

# Display the number of rows and percentage in Jupyter notebook
print(f'The filtered dataset based on the repositories with morethan 500 stars has {num_rows} rows, which is {percentage:.2f}% of the filtered dataset based on repositories with label feature.')
# Out:
# The filtered dataset based on the repositories with morethan 500 stars has 3971 rows, which is 21.72% of the filtered dataset based on repositories with label feature.

# %%
# Count the number of rows in the dataframe
data_num_rows = filtered_df.shape[0]

# Display the number of rows
print(f'The dataset with stargazers above 500 has {data_num_rows} rows.')

# Filter the data based on the criteria
filtered_df = filtered_df[(filtered_df['totalIssues'] > 20)]

# Count the number of rows in the filtered dataframe
num_rows = filtered_df.shape[0]

# Calculate the percentage of rows that passed the filtering criteria
percentage = num_rows / data_num_rows * 100

# Export the new dataframe to a CSV file
filtered_df.to_csv('seed_dataset.csv', index=False)

# Display the number of rows and percentage in Jupyter notebook
print(f'The filtered dataset based on the repositories with more than 20 total issues has {num_rows} rows, which is {percentage:.2f}% of the stargazers dataset')
# Out:
# The dataset with stargazers above 500 has 3971 rows.
# The filtered dataset based on the repositories with more than 20 total issues has 3823 rows, which is 96.27% of the stargazers dataset

# %%
# Filter the data based on the criteria
filtered_df = filtered_df[filtered_df['totalIssues'] > 50]

# Take a random sample of 100 rows
sample_df = filtered_df.sample(n=100, random_state=42)

# Export the new dataframe to a CSV file
sample_df.to_csv('sample_features_dataset.csv', index=False)

# Count the number of rows in the filtered dataframe
num_rows = filtered_df.shape[0]

# Display the number of rows and percentage in Jupyter notebook
print(f'The filtered dataset based on the repositories with more than 50 total issues has {num_rows} rows')


# Display the resulting DataFrame
filtered_df
# Out:
# The filtered dataset based on the repositories with more than 50 total issues has 3574 rows
#              id                               name  isFork  commits  branches  \
# 0           468                  junit-team/junit4   False   2507.0         5
# 1           472              connectbot/connectbot   False   2138.0        11
# 7          2059                          jdbi/jdbi   False   5136.0        39
# 11         4161                 sirthias/parboiled   False    855.0         4
# 13         4800                     trifork/erjang   False   1701.0        11
# ...         ...                                ...     ...      ...       ...
# 18225  89978807       scratchfoundation/scratch-vm   False   5367.0       508
# 18227  90034473        qin2dim/hcaptcha-challenger   False    281.0         1
# 18237  90202434                        apache/brpc   False   2960.0         8
# 18248  90378263              withsecurelabs/drozer   False   1124.0         6
# ...
